# %% [markdown]
# # VizDoom Basic Runnning

# %% [markdown]
# ## Step 1: Installing VizDoom

# %%
pip install vizdoom ## free opensource library for running DOOM through python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting vizdoom
#   Downloading vizdoom-1.2.4-cp39-cp39-win_amd64.whl (15.5 MB)
#      -------------------------------------- 15.5/15.5 MB 540.7 kB/s eta 0:00:00
# Collecting pygame>=2.1.3
#   Downloading pygame-2.6.1-cp39-cp39-win_amd64.whl (10.6 MB)
#      -------------------------------------- 10.6/10.6 MB 522.6 kB/s eta 0:00:00
# Requirement already satisfied: gymnasium>=0.28.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from vizdoom) (1.0.0)
# Requirement already satisfied: numpy in c:\users\kiit\appdata\roaming\python\python39\site-packages (from vizdoom) (1.21.6)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from gymnasium>=0.28.0->vizdoom) (4.12.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (4.11.3)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from gymnasium>=0.28.0->vizdoom) (0.0.4)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium>=0.28.0->vizdoom) (3.8.0)
# Installing collected packages: pygame, vizdoom
# Successfully installed pygame-2.6.1 vizdoom-1.2.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)

# %%
# !cd github

# %%
pip install git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)

# %%
# !cd github & git clone https://github.com/Farama-Foundation/ViZDoom
# Out:
# Cloning into 'ViZDoom'...
# Updating files:  53% (1110/2058)
# Updating files:  54% (1112/2058)
# Updating files:  55% (1132/2058)
# Updating files:  56% (1153/2058)
# Updating files:  57% (1174/2058)
# Updating files:  58% (1194/2058)
# Updating files:  59% (1215/2058)
# Updating files:  60% (1235/2058)
# Updating files:  61% (1256/2058)
# Updating files:  62% (1276/2058)
# Updating files:  63% (1297/2058)
# Updating files:  64% (1318/2058)
# Updating files:  65% (1338/2058)
# Updating files:  66% (1359/2058)
# Updating files:  67% (1379/2058)
# Updating files:  68% (1400/2058)
# Updating files:  69% (1421/2058)
# Updating files:  70% (1441/2058)
# Updating files:  71% (1462/2058)
# Updating files:  72% (1482/2058)
# Updating files:  73% (1503/2058)
# Updating files:  74% (1523/2058)
# Updating files:  75% (1544/2058)
# Updating files:  76% (1565/2058)
# Updating files:  77% (1585/2058)
# Updating files:  78% (1606/2058)
# Updating files:  79% (1626/2058)
# Updating files:  80% (1647/2058)
# Updating files:  81% (1667/2058)
# Updating files:  82% (1688/2058)
# Updating files:  83% (1709/2058)
# Updating files:  84% (1729/2058)
# Updating files:  85% (1750/2058)
# Updating files:  86% (1770/2058)
# Updating files:  87% (1791/2058)
# Updating files:  88% (1812/2058)
# Updating files:  89% (1832/2058)
# Updating files:  90% (1853/2058)
# Updating files:  91% (1873/2058)
# Updating files:  92% (1894/2058)
# Updating files:  93% (1914/2058)
# Updating files:  94% (1935/2058)
# Updating files:  95% (1956/2058)
# Updating files:  96% (1976/2058)
# Updating files:  97% (1997/2058)
# Updating files:  98% (2017/2058)
# Updating files:  99% (2038/2058)
# Updating files: 100% (2058/2058)
# Updating files: 100% (2058/2058), done.

# %%
# Imports 
from vizdoom import * # every vizdoom dependancy
# for game model
import random
import time
import numpy as np

# %%
# GAME SETUP

game = DoomGame()
game.load_config('github/ViZDoom/scenarios/basic.cfg')
game.init()

# %%
# ACTIONS ARE MOVE_LEFT, MOVE_RIGHT, ATTACK

# LEFT = [1, 0, 0]
# RIGHT = [0, 1, 0]
# ATTACK = [0, 0, 1]

# %%
actions = np.identity(3, dtype = np.uint8)
# the identity matrix acts as actions

# %%
actions
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]], dtype=uint8)

# %%
# checking with random actions to simulate random events
random.choice(actions)
# Out:
# array([1, 0, 0], dtype=uint8)

# %%
game.new_episode()

# %%
game.make_action(random.choice(actions))
# Out:
# -1.0

# %%
state = game.get_state()

# %%
state.screen_buffer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12972\463077609.py in <module>
# ----> 1 state.screen_buffer
#
# AttributeError: 'NoneType' object has no attribute 'screen_buffer'

# %%
game.close()

# %%
# using random actions to visualise our environment
episodes = 100
for episode in range(episodes):
    game.new_episode()
    while not game.is_episode_finished():
        game.make_action(random.choice(actions))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31228\716412175.py in <module>
#       4     game.new_episode()
#       5     while not game.is_episode_finished():
# ----> 6         game.make_action(random.choice(actions))
#       7
#
# KeyboardInterrupt:

# %%
# now setting up a basic reward function
episodes = 100
for episode in range(episodes):
    game.new_episode() # making new episode (new game)
    while not game.is_episode_finished(): # looping while the game is not finished
        state = game.get_state() # to assess current state of the game
        #stats about current state
        img = state.screen_buffer # gets the frame of the game
        info = state.game_variables # game variables -> 50 ammo
        # the 4 is passing no of frame skips so that the game sees the choice made
        reward = game.make_action(random.choice(actions), 4) # any random choice for the player
        
        # live reward function printing
        print("Reward: ", reward)
        time.sleep(.009)
    print("Reward result: ", game.get_total_reward())
    time.sleep(1)
# Out:
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward result:  -375.0
# Reward:  -4.0
# Reward:  99.0
# Reward result:  95.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  99.0
# Reward result:  91.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  99.0
# Reward result:  91.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  97.0
# Reward:  -1.0
# Reward result:  43.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward result:  -365.0
# Reward:  -4.0
# Reward:  99.0
# Reward result:  95.0
# Reward:  -4.0
# Reward:  99.0
# Reward result:  95.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  99.0
# Reward result:  87.0
# Reward:  -4.0
# Reward:  99.0
# Reward result:  95.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward result:  -370.0
# Reward:  -4.0
# Reward:  99.0
# Reward result:  95.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  99.0
# Reward result:  66.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward result:  -375.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward result:  -370.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -4.0
# Reward:  -9.0
# Reward:  -4.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31228\731556538.py in <module>
#       8         img = state.screen_buffer # gets the frame of the game
#       9         info = state.game_variables # game variables -> 50 ammo
# ---> 10         reward = game.make_action(random.choice(actions), 4) # any random choice for the player
#      11         # live reward function printing
#      12         print("Reward: ", reward)
#
# KeyboardInterrupt:

# %%
game.close()

# %% [markdown]
# # Setting up VizDoom on OpenAI Gym Environment

# %%
# !pip install gym
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gym in c:\users\kiit\appdata\roaming\python\python39\site-packages (0.26.2)
# Requirement already satisfied: gym_notices>=0.0.4 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from gym) (0.0.8)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from gym) (1.21.6)
# Requirement already satisfied: importlib_metadata>=4.8.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from gym) (8.5.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gym) (2.0.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from importlib_metadata>=4.8.0->gym) (3.21.0)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)

# %%
# Imports from OpenAI Gym
from gymnasium import Env
#importing gym spaces
from gymnasium.spaces import Discrete, Box
import cv2

# %%
Discrete(3).sample() # using this we can randomly sample from the action space
# Out:
# 0

# %%
actions[Discrete(3).sample()]
# Out:
# array([1, 0, 0], dtype=uint8)

# %%
Box(low=0, high=255, shape=(320,240), dtype = np.uint8).sample() # gives image
# Out:
# array([[193,  85,  60, ..., 222,  28,  10],
#        [150, 177, 175, ...,  88, 153, 122],
#        [137, 235, 176, ..., 169, 155, 161],
#        ...,
#        [151, 146,  69, ..., 138, 108, 134],
#        [ 84,  89, 101, ..., 105,  96,   0],
#        [250,  55, 102, ...,  27, 130,  57]], dtype=uint8)

# %%
game.get_state().screen_buffer.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12972\895764004.py in <module>
# ----> 1 game.get_state().screen_buffer.shape
#
# AttributeError: 'NoneType' object has no attribute 'screen_buffer'

# %% [markdown]
# ### Defining Classes

# %%
import numpy as np
import cv2
from vizdoom import DoomGame
from gymnasium import Env
from gymnasium.spaces import Box, Discrete

# %%
class VizDoomGym(Env):    
    def __init__(self, render=False):
        super().__init__()
        self.game = DoomGame()
        self.game.load_config('github/ViZDoom/scenarios/basic.cfg')

        self.game.set_window_visible(render)
        self.game.init()

        self.observation_space = Box(low=0, high=255, shape=(100, 160, 1), dtype=np.uint8)
        self.action_space = Discrete(3)

    def step(self, action):
        actions = np.identity(3, dtype=np.uint8)
        reward = self.game.make_action(actions[action], 4)

        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = {"ammo": ammo}
        else:
            state = np.zeros(self.observation_space.shape, dtype=np.uint8)
            info = {}

        done = self.game.is_episode_finished()
        return state, reward, done, False, info  # False for 'truncated' (new Gymnasium API)

    def render(self):
        pass

    def reset(self, seed=None, options=None):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state), {}

    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160, 100), interpolation=cv2.INTER_CUBIC)
        return np.reshape(resize, (100, 160, 1))

    def close(self):
        self.game.close()

# %%
env = VizDoomGym() # without render

# %%
env = VizDoomGym(render = True)

# %%
env.observation_space.shape
# Out:
# (100, 160, 1)

# %%
state = env.reset()

# %%
state.shape # no longer any color channel
# Out:
# (100, 160, 1)

# %%
np.moveaxis(state, 0, -1).shape
# Out:
# (240, 320, 3)

# %%
env.close()

# %%
# importing env checker
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env) # if no output then env is working fine.

# %% [markdown]
# # Visualising State

# %%
# Extract the state from the tuple
state, _ = env.reset()

# Since the image is already grayscale, no need to convert to RGB
plt.imshow(state.squeeze(), cmap='gray')  # Use .squeeze() to remove the extra channel dimension
plt.show()

# %% [markdown]
# # Making the Callback Function

# %%
#Installing pytorch
# !pip3 install torch torchvision torchaudio
# Out:
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Using cached torch-2.6.0-cp39-cp39-win_amd64.whl (204.1 MB)
# Requirement already satisfied: torchvision in c:\users\kiit\appdata\roaming\python\python39\site-packages (0.20.1+cpu)
# Requirement already satisfied: torchaudio in c:\users\kiit\appdata\roaming\python\python39\site-packages (2.5.1+cpu)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: filelock in c:\users\kiit\appdata\roaming\python\python39\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from torch) (4.12.2)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch) (2022.7.1)
# Requirement already satisfied: jinja2 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from torch) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.2.1)
#   Downloading torch-2.5.1-cp39-cp39-win_amd64.whl (203.0 MB)
#      -------------------------------------- 203.0/203.0 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: numpy in c:\users\kiit\appdata\roaming\python\python39\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch) (2.0.1)
# Installing collected packages: torch
# Successfully installed torch-2.5.1

# %%
# Installing Stable Baselines
# !pip install stable-baselines3[extra]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3[extra] in c:\users\kiit\appdata\roaming\python\python39\site-packages (2.4.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.4.4)
# Collecting numpy<2.0,>=1.20
#   Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
#      -------------------------------------- 15.8/15.8 MB 615.5 kB/s eta 0:00:00
# Collecting torch>=1.13
#   Using cached torch-2.6.0-cp39-cp39-win_amd64.whl (204.1 MB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.5.2)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: ale-py>=0.9.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (0.10.1)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (10.3.0)
# Requirement already satisfied: opencv-python in c:\users\kiit\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (4.8.1.78)
# Collecting tensorboard>=2.9.1
#   Using cached tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: pygame in c:\users\kiit\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.64.1)
# Requirement already satisfied: rich in c:\users\kiit\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (13.7.1)
# Requirement already satisfied: importlib-metadata>=4.10.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from ale-py>=0.9.0->stable-baselines3[extra]) (8.5.0)
# Requirement already satisfied: typing-extensions in c:\users\kiit\appdata\roaming\python\python39\site-packages (from ale-py>=0.9.0->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: six>1.9 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (63.4.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.59.0)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2022.7.1)
# Requirement already satisfied: jinja2 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.5)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2.8.4)
# Requirement already satisfied: sympy==1.13.1 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: filelock in c:\users\kiit\appdata\roaming\python\python39\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3[extra]) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from rich->stable-baselines3[extra]) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.5)
# Requirement already satisfied: zipp>=3.20 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.10.0->ale-py>=0.9.0->stable-baselines3[extra]) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.13->stable-baselines3[extra]) (2.0.1)
# Installing collected packages: numpy, torch, tensorboard
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\KIIT\\AppData\\Roaming\\Python\\Python39\\site-packages\\~-mpy.libs\\libscipy_openblas64_-caad452230ae4ddb57899b8b3a33c55c.dll'
# Check the permissions.
#
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)

# %%
# IMPORTING DEPENDANCIES
import os
import torch
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainingLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose = 1):
        super(TrainingLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
        
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok = True)
            
    def _on_step(self):
        if (self.n_calls % self.check_freq == 0):
            model_path = os.path.join(self.save_path, 'model_{}'.format(self.n_calls))
            self.model.save(model_path)
        
        return True

# %%
Check_Dir = './train/train_basic/'
Log_Dir = './logs/logs_basic/'

# %%
callback = TrainingLoggingCallback(check_freq=10000, save_path=Check_Dir)

# %% [markdown]
# # Training

# %%
# !pip install tensorboard
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorboard in c:\users\kiit\appdata\roaming\python\python39\site-packages (2.18.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorboard) (21.3)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from tensorboard) (1.59.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from tensorboard) (0.7.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard) (3.3.4)
# Requirement already satisfied: six>1.9 in c:\programdata\anaconda3\lib\site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard) (2.0.3)
# Requirement already satisfied: absl-py>=0.4 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from tensorboard) (2.0.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard) (63.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->tensorboard) (3.0.9)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\kiit\appdata\roaming\python\python39\site-packages)

# %%
import tensorboard
print(tensorboard.__version__)
# Out:
# 2.18.0

# %%
# Using PPO algorithm
from stable_baselines3 import PPO

# %%
env = VizDoomGym() # creating environment without rendering for better training

# %%
model = PPO('CnnPolicy', env, tensorboard_log=Log_Dir, verbose = 1, learning_rate=0.0002, n_steps = 1024)
# Cnn because image, tensorboard log goes to the log directory, verbose to give info while training
# n_steps should be close to full no of episodes (300 for basic Doom) but not complete usually
# its the no. of frames the agent will use
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/logs_basic/PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.7     |
# |    ep_rew_mean     | -59.8    |
# | time/              |          |
# |    fps             | 14       |
# |    iterations      | 1        |
# |    time_elapsed    | 69       |
# |    total_timesteps | 1024     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.4        |
# |    ep_rew_mean          | -62.5       |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 2           |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.004252162 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -7.63e-06   |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.0173      |
# |    value_loss           | 2.63e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.1        |
# |    ep_rew_mean          | -62.2       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 3           |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.010170229 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.28e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00769    |
# |    value_loss           | 2.87e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.1       |
# |    ep_rew_mean          | -56.8      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 4          |
# |    time_elapsed         | 350        |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.02253985 |
# |    clip_fraction        | 0.337      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 1.12e+03   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00105   |
# |    value_loss           | 2.72e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | -43.1       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 5           |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.008350951 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.55e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00988     |
# |    value_loss           | 2.87e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.6         |
# |    ep_rew_mean          | -13.5        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 6            |
# |    time_elapsed         | 537          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0128678465 |
# |    clip_fraction        | 0.278        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.475        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.28e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | 0.00832      |
# |    value_loss           | 3.78e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.3       |
# |    ep_rew_mean          | -22.2      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 7          |
# |    time_elapsed         | 635        |
# |    total_timesteps      | 7168       |
# | train/                  |            |
# |    approx_kl            | 0.27333027 |
# |    clip_fraction        | 0.36       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.902     |
# |    explained_variance   | 0.631      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 1.2e+03    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.0181     |
# |    value_loss           | 2.83e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23          |
# |    ep_rew_mean          | -42.6       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 8           |
# |    time_elapsed         | 726         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.042113923 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.332      |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 761         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00389     |
# |    value_loss           | 1.49e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.9        |
# |    ep_rew_mean          | -50.5       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 9           |
# |    time_elapsed         | 819         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.019569583 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.152      |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 470         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.00747     |
# |    value_loss           | 1.73e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.9         |
# |    ep_rew_mean          | -71.6        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 10           |
# |    time_elapsed         | 913          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0007429381 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.063       |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.08e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.000269     |
# |    value_loss           | 4.44e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 31.8          |
# |    ep_rew_mean          | -106          |
# | time/                   |               |
# |    fps                  | 11            |
# |    iterations           | 11            |
# |    time_elapsed         | 1007          |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 0.00030491408 |
# |    clip_fraction        | 0.00547       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0748       |
# |    explained_variance   | 0.616         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 1.46e+03      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 0.000474      |
# |    value_loss           | 2.98e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.5         |
# |    ep_rew_mean          | -124         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 12           |
# |    time_elapsed         | 1101         |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0033015101 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0895      |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 558          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00206      |
# |    value_loss           | 2.42e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.2        |
# |    ep_rew_mean          | -135        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 13          |
# |    time_elapsed         | 1197        |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.011841372 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.215      |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.24e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00342     |
# |    value_loss           | 1.91e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.7         |
# |    ep_rew_mean          | -103         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 14           |
# |    time_elapsed         | 1291         |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0033059916 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.154       |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 479          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.00316      |
# |    value_loss           | 1.37e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.7        |
# |    ep_rew_mean          | -59.2       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 15          |
# |    time_elapsed         | 1387        |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.081366226 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.232      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 668         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00269    |
# |    value_loss           | 1.9e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.1       |
# |    ep_rew_mean          | -50.8      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 16         |
# |    time_elapsed         | 1483       |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.30770388 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.45      |
# |    explained_variance   | 0.74       |
# |    learning_rate        | 0.0002     |
# |    loss                 | 503        |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.0185     |
# |    value_loss           | 1.08e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.5        |
# |    ep_rew_mean          | -52.6       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 17          |
# |    time_elapsed         | 1578        |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.028861415 |
# |    clip_fraction        | 0.0043      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0498     |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.09e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 1.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.4        |
# |    ep_rew_mean          | -51.6       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 18          |
# |    time_elapsed         | 1673        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.028501434 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.185      |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 459         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0103      |
# |    value_loss           | 912         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.8        |
# |    ep_rew_mean          | -27.2       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 19          |
# |    time_elapsed         | 1770        |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.023280669 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.262      |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 684         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00897     |
# |    value_loss           | 1.48e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.3        |
# |    ep_rew_mean          | -1.97       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 20          |
# |    time_elapsed         | 1867        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012394998 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.261      |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 375         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0106      |
# |    value_loss           | 945         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.6       |
# |    ep_rew_mean          | -23.5      |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 21         |
# |    time_elapsed         | 1964       |
# |    total_timesteps      | 21504      |
# | train/                  |            |
# |    approx_kl            | 0.08438292 |
# |    clip_fraction        | 0.0721     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.236     |
# |    explained_variance   | 0.884      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 415        |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.0144     |
# |    value_loss           | 1.16e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.2        |
# |    ep_rew_mean          | -39.7       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 22          |
# |    time_elapsed         | 2060        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.016272577 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.236      |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 635         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00379    |
# |    value_loss           | 1.42e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 26         |
# |    ep_rew_mean          | -63.1      |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 23         |
# |    time_elapsed         | 2155       |
# |    total_timesteps      | 23552      |
# | train/                  |            |
# |    approx_kl            | 0.19415283 |
# |    clip_fraction        | 0.0844     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.155     |
# |    explained_variance   | 0.818      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 470        |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.0115     |
# |    value_loss           | 2.42e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.7        |
# |    ep_rew_mean          | -18.1       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 24          |
# |    time_elapsed         | 2254        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.029617563 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.294      |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 369         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0397     |
# |    value_loss           | 1.1e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.7       |
# |    ep_rew_mean          | -1.53      |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 25         |
# |    time_elapsed         | 2353       |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.03294731 |
# |    clip_fraction        | 0.0879     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.293     |
# |    explained_variance   | 0.789      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 403        |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.0129     |
# |    value_loss           | 1.32e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.6         |
# |    ep_rew_mean          | -21.8        |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 26           |
# |    time_elapsed         | 2448         |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0037414576 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.157       |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 568          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.0051       |
# |    value_loss           | 1.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.3         |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 27           |
# |    time_elapsed         | 2544         |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0028125355 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.124       |
# |    explained_variance   | 0.879        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 391          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.00145      |
# |    value_loss           | 928          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.4         |
# |    ep_rew_mean          | -38.1        |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 28           |
# |    time_elapsed         | 2640         |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0040018335 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.129       |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 751          |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.0015       |
# |    value_loss           | 1.29e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | -38.7       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 29          |
# |    time_elapsed         | 2737        |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.003327489 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.195      |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 408         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 1.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.5        |
# |    ep_rew_mean          | -23.8       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 30          |
# |    time_elapsed         | 2834        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.026499685 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.198      |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 883         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00379     |
# |    value_loss           | 1.92e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.2        |
# |    ep_rew_mean          | -23.6       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 31          |
# |    time_elapsed         | 2930        |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.025445182 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.169      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 255         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0178      |
# |    value_loss           | 965         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.7       |
# |    ep_rew_mean          | -56.6      |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 32         |
# |    time_elapsed         | 3023       |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.46955618 |
# |    clip_fraction        | 0.0911     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0579    |
# |    explained_variance   | 0.885      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 260        |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0281     |
# |    value_loss           | 876        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 26.5      |
# |    ep_rew_mean          | -66.7     |
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 33        |
# |    time_elapsed         | 3120      |
# |    total_timesteps      | 33792     |
# | train/                  |           |
# |    approx_kl            | 0.5716091 |
# |    clip_fraction        | 0.148     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.131    |
# |    explained_variance   | 0.714     |
# |    learning_rate        | 0.0002    |
# |    loss                 | 278       |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.0287   |
# |    value_loss           | 787       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.6       |
# |    ep_rew_mean          | 1.69       |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 34         |
# |    time_elapsed         | 3217       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.03570586 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.228     |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 353        |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00547   |
# |    value_loss           | 780        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.2        |
# |    ep_rew_mean          | 16.1        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 35          |
# |    time_elapsed         | 3317        |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.001471367 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.144      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 324         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00317     |
# |    value_loss           | 679         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.3         |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 36           |
# |    time_elapsed         | 3416         |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0074494537 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.131       |
# |    explained_variance   | 0.908        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 253          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.000947     |
# |    value_loss           | 1.11e+03     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 16.1      |
# |    ep_rew_mean          | 3.88      |
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 37        |
# |    time_elapsed         | 3514      |
# |    total_timesteps      | 37888     |
# | train/                  |           |
# |    approx_kl            | 0.0064751 |
# |    clip_fraction        | 0.0717    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.182    |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0002    |
# |    loss                 | 225       |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -0.00286  |
# |    value_loss           | 495       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.8         |
# |    ep_rew_mean          | 4.66         |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 38           |
# |    time_elapsed         | 3612         |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0074310307 |
# |    clip_fraction        | 0.0725       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.129       |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 211          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.00305      |
# |    value_loss           | 553          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 15.9       |
# |    ep_rew_mean          | 2.68       |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 39         |
# |    time_elapsed         | 3708       |
# |    total_timesteps      | 39936      |
# | train/                  |            |
# |    approx_kl            | 0.00796485 |
# |    clip_fraction        | 0.0457     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.111     |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 187        |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.00273    |
# |    value_loss           | 452        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.6        |
# |    ep_rew_mean          | -3.71       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 40          |
# |    time_elapsed         | 3807        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011973551 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0799     |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 204         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00541     |
# |    value_loss           | 994         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.3         |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 41           |
# |    time_elapsed         | 3904         |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0030126642 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0685      |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 121          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.00309      |
# |    value_loss           | 255          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.1         |
# |    ep_rew_mean          | -26.8        |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 42           |
# |    time_elapsed         | 4001         |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0027259907 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.105       |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 111          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.00283      |
# |    value_loss           | 382          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.5         |
# |    ep_rew_mean          | 4.57         |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 43           |
# |    time_elapsed         | 4099         |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0008542893 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0535      |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 55.2         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.00121      |
# |    value_loss           | 168          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.8        |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 44          |
# |    time_elapsed         | 4199        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007205488 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.134      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 52.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00034    |
# |    value_loss           | 146         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.1        |
# |    ep_rew_mean          | 0.57        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 45          |
# |    time_elapsed         | 4296        |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.021803685 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.12       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 61.3        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00414     |
# |    value_loss           | 165         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.3         |
# |    ep_rew_mean          | -14.7        |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 46           |
# |    time_elapsed         | 4391         |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0044738078 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0778      |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 45.1         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.000566     |
# |    value_loss           | 118          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.6        |
# |    ep_rew_mean          | -24.1       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 47          |
# |    time_elapsed         | 4489        |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.014576705 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0713     |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 132         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00308     |
# |    value_loss           | 510         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.6         |
# |    ep_rew_mean          | -37.8        |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 48           |
# |    time_elapsed         | 4583         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0044304673 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0753      |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 91.7         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00305      |
# |    value_loss           | 325          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.4        |
# |    ep_rew_mean          | -56.2       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 49          |
# |    time_elapsed         | 4682        |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.002269769 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0542     |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 99.8        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.002       |
# |    value_loss           | 206         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.9         |
# |    ep_rew_mean          | -31.1        |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 50           |
# |    time_elapsed         | 4778         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0040588835 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0838      |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 167          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.00112      |
# |    value_loss           | 697          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.1        |
# |    ep_rew_mean          | -19.2       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 51          |
# |    time_elapsed         | 4877        |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.017087752 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.105      |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 195         |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.0163      |
# |    value_loss           | 558         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17.3       |
# |    ep_rew_mean          | -2.22      |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 52         |
# |    time_elapsed         | 4979       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.07170407 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.168     |
# |    explained_variance   | 0.909      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 114        |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.0132     |
# |    value_loss           | 905        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 19.9       |
# |    ep_rew_mean          | -19.6      |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 53         |
# |    time_elapsed         | 5076       |
# |    total_timesteps      | 54272      |
# | train/                  |            |
# |    approx_kl            | 0.08030845 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.267     |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 335        |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.0202     |
# |    value_loss           | 1.01e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.2       |
# |    ep_rew_mean          | -26.1      |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 54         |
# |    time_elapsed         | 5175       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.02004205 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.305     |
# |    explained_variance   | 0.911      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 173        |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0108     |
# |    value_loss           | 549        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19          |
# |    ep_rew_mean          | -9.33       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 55          |
# |    time_elapsed         | 5276        |
# |    total_timesteps      | 56320       |
# | train/                  |             |
# |    approx_kl            | 0.041290656 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.325      |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 297         |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.0201      |
# |    value_loss           | 729         |
# ...
# |    total_timesteps      | 495616    |
# | train/                  |           |
# |    approx_kl            | 0.3751555 |
# |    clip_fraction        | 0.0938    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0655   |
# |    explained_variance   | 0.781     |
# |    learning_rate        | 0.0002    |
# |    loss                 | 0.548     |
# |    n_updates            | 4830      |
# |    policy_gradient_loss | -0.00682  |
# |    value_loss           | 3.79      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.5       |
# |    ep_rew_mean          | 29.3       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 485        |
# |    time_elapsed         | 52323      |
# |    total_timesteps      | 496640     |
# | train/                  |            |
# |    approx_kl            | 0.07146022 |
# |    clip_fraction        | 0.0595     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0322    |
# |    explained_variance   | 0.712      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 196        |
# |    n_updates            | 4840       |
# |    policy_gradient_loss | 0.0126     |
# |    value_loss           | 448        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.27       |
# |    ep_rew_mean          | 68.8       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 486        |
# |    time_elapsed         | 52425      |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.05206091 |
# |    clip_fraction        | 0.0542     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0382    |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.0002     |
# |    loss                 | 368        |
# |    n_updates            | 4850       |
# |    policy_gradient_loss | 0.00125    |
# |    value_loss           | 790        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.28        |
# |    ep_rew_mean          | 62.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 487         |
# |    time_elapsed         | 52529       |
# |    total_timesteps      | 498688      |
# | train/                  |             |
# |    approx_kl            | 0.047974102 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0252     |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 216         |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | 0.00677     |
# |    value_loss           | 703         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.23         |
# |    ep_rew_mean          | 74.8         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 488          |
# |    time_elapsed         | 52634        |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0059039504 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0259      |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 130          |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | 0.00147      |
# |    value_loss           | 782          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.99        |
# |    ep_rew_mean          | 80.8        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 489         |
# |    time_elapsed         | 52739       |
# |    total_timesteps      | 500736      |
# | train/                  |             |
# |    approx_kl            | 0.054755807 |
# |    clip_fraction        | 0.0483      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.023      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 524         |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | 0.00253     |
# |    value_loss           | 520         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.43        |
# |    ep_rew_mean          | 84.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 490         |
# |    time_elapsed         | 52850       |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.026851336 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0456     |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 732         |
# |    n_updates            | 4890        |
# |    policy_gradient_loss | 0.00144     |
# |    value_loss           | 987         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.93        |
# |    ep_rew_mean          | 87.3        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 491         |
# |    time_elapsed         | 52964       |
# |    total_timesteps      | 502784      |
# | train/                  |             |
# |    approx_kl            | 0.030670788 |
# |    clip_fraction        | 0.0257      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0271     |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 594         |
# |    n_updates            | 4900        |
# |    policy_gradient_loss | 0.000164    |
# |    value_loss           | 624         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.13        |
# |    ep_rew_mean          | 86          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 492         |
# |    time_elapsed         | 53077       |
# |    total_timesteps      | 503808      |
# | train/                  |             |
# |    approx_kl            | 0.084131435 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0197     |
# |    explained_variance   | -0.447      |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.527       |
# |    n_updates            | 4910        |
# |    policy_gradient_loss | 0.00413     |
# |    value_loss           | 11.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.9        |
# |    ep_rew_mean          | 87.3       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 493        |
# |    time_elapsed         | 53191      |
# |    total_timesteps      | 504832     |
# | train/                  |            |
# |    approx_kl            | 0.08581698 |
# |    clip_fraction        | 0.0333     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0136    |
# |    explained_variance   | 0.766      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 7.89       |
# |    n_updates            | 4920       |
# |    policy_gradient_loss | -0.00796   |
# |    value_loss           | 29.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.78       |
# |    ep_rew_mean          | 87.8       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 494        |
# |    time_elapsed         | 53300      |
# |    total_timesteps      | 505856     |
# | train/                  |            |
# |    approx_kl            | 0.39029288 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.101     |
# |    explained_variance   | 0.939      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 0.23       |
# |    n_updates            | 4930       |
# |    policy_gradient_loss | -0.0196    |
# |    value_loss           | 3.68       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.81      |
# |    ep_rew_mean          | 87.7      |
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 495       |
# |    time_elapsed         | 53417     |
# |    total_timesteps      | 506880    |
# | train/                  |           |
# |    approx_kl            | 0.3409112 |
# |    clip_fraction        | 0.196     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0576   |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0002    |
# |    loss                 | 2.18      |
# |    n_updates            | 4940      |
# |    policy_gradient_loss | -0.018    |
# |    value_loss           | 4.02      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4.06      |
# |    ep_rew_mean          | 86.2      |
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 496       |
# |    time_elapsed         | 53527     |
# |    total_timesteps      | 507904    |
# | train/                  |           |
# |    approx_kl            | 0.1473428 |
# |    clip_fraction        | 0.119     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0773   |
# |    explained_variance   | 0.962     |
# |    learning_rate        | 0.0002    |
# |    loss                 | 0.6       |
# |    n_updates            | 4950      |
# |    policy_gradient_loss | 0.0166    |
# |    value_loss           | 3.36      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.68       |
# |    ep_rew_mean          | 88.3       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 497        |
# |    time_elapsed         | 53643      |
# |    total_timesteps      | 508928     |
# | train/                  |            |
# |    approx_kl            | 0.43197435 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.082     |
# |    explained_variance   | 0.562      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 17         |
# |    n_updates            | 4960       |
# |    policy_gradient_loss | -0.00802   |
# |    value_loss           | 70.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.64       |
# |    ep_rew_mean          | 88.4       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 498        |
# |    time_elapsed         | 53759      |
# |    total_timesteps      | 509952     |
# | train/                  |            |
# |    approx_kl            | 0.04073663 |
# |    clip_fraction        | 0.0415     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0606    |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 0.596      |
# |    n_updates            | 4970       |
# |    policy_gradient_loss | 0.00773    |
# |    value_loss           | 2.25       |
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18932\1601964785.py in <module>
# ----> 1 model.learn(total_timesteps=1000000, callback=callback)
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309         progress_bar: bool = False,
#     310     ) -> SelfPPO:
# --> 311         return super().learn(
#     312             total_timesteps=total_timesteps,
#     313             callback=callback,
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321
#     322         while self.num_timesteps < total_timesteps:
# --> 323             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     324
#     325             if not continue_training:
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     216                     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     217
# --> 218             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     219
#     220             self.num_timesteps += env.num_envs
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     204         """
#     205         self.step_async(actions)
# --> 206         return self.step_wait()
#     207
#     208     def get_images(self) -> Sequence[Optional[np.ndarray]]:
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\vec_env\vec_transpose.py in step_wait(self)
#      95
#      96     def step_wait(self) -> VecEnvStepReturn:
# ---> 97         observations, rewards, dones, infos = self.venv.step_wait()
#      98
#      99         # Transpose the terminal observations
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      56         # Avoid circular imports
#      57         for env_idx in range(self.num_envs):
# ---> 58             obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59                 self.actions[env_idx]
#      60             )
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\monitor.py in step(self, action)
#      92         if self.needs_reset:
#      93             raise RuntimeError("Tried to step environment that needs reset")
# ---> 94         observation, reward, terminated, truncated, info = self.env.step(action)
#      95         self.rewards.append(float(reward))
#      96         if terminated or truncated:
#
# ~\AppData\Local\Temp\ipykernel_18932\1766084355.py in step(self, action)
#      13     def step(self, action):
#      14         actions = np.identity(3, dtype=np.uint8)
# ---> 15         reward = self.game.make_action(actions[action], 4)
#      16
#      17         if self.game.get_state():
#
# KeyboardInterrupt:

# %%
print("Training Done")
# Out:
# Training Done

# %% [markdown]
# # Testing Trained Model

# %%
# Using stable baselines to evaluate model through builtin evaluation function
from stable_baselines3.common.evaluation import evaluate_policy

# %%
model = PPO.load('./train/train_basic/model_800000.zip')

# %%
env = VizDoomGym(render = True)

# %%
env.close()

# %%
mean_reward,_ = evaluate_policy(model, env, n_eval_episodes=1)

# %%
mean_reward
# Out:
# 95.0
